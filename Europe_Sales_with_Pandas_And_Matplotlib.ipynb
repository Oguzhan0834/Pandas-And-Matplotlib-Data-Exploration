# %%
# importing library to be used 
import pandas as pd

# %%
# importing file to be used
EuropeSales = pd.read_csv("input/Europe Sales Records.csv")
EuropeSales
# Out:
#       Region                 Country        Item Type Sales Channel  \
# 0     Europe          Czech Republic        Beverages       Offline
# 1     Europe  Bosnia and Herzegovina          Clothes        Online
# 2     Europe                 Austria           Cereal       Offline
# 3     Europe                Bulgaria  Office Supplies        Online
# 4     Europe                 Estonia           Fruits        Online
# ...      ...                     ...              ...           ...
# 1325  Europe                  Norway    Personal Care       Offline
# 1326  Europe                 Ukraine           Cereal       Offline
# 1327  Europe                 Armenia             Meat       Offline
# 1328  Europe                 Denmark          Clothes       Offline
# 1329  Europe                 Finland          Clothes        Online
#
#      Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0                 C   9/12/2011  478051030   9/29/2011        4778
# ...

# %%
# Showing first 5 rows 
EuropeSales.head()
# Out:
#    Region                 Country        Item Type Sales Channel  \
# 0  Europe          Czech Republic        Beverages       Offline
# 1  Europe  Bosnia and Herzegovina          Clothes        Online
# 2  Europe                 Austria           Cereal       Offline
# 3  Europe                Bulgaria  Office Supplies        Online
# 4  Europe                 Estonia           Fruits        Online
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              C   9/12/2011  478051030   9/29/2011        4778       47.45
# 1              M  10/14/2013  919133651   11/4/2013         927      109.28
# 2              C   8/13/2014  987410676    9/6/2014        5616      205.70
# 3              L  10/31/2010  672330081  11/29/2010        6266      651.21
# 4              L   9/28/2016  579463422   11/1/2016        4958        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      31.79      226716.10   151892.62      74823.48
# ...

# %%
# Showing last 5 rows
EuropeSales.tail()
# Out:
#       Region  Country      Item Type Sales Channel Order Priority Order Date  \
# 1325  Europe   Norway  Personal Care       Offline              M  1/14/2014
# 1326  Europe  Ukraine         Cereal       Offline              L  4/14/2014
# 1327  Europe  Armenia           Meat       Offline              M  11/9/2015
# 1328  Europe  Denmark        Clothes       Offline              H   5/9/2012
# 1329  Europe  Finland        Clothes        Online              L  4/22/2014
#
#        Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 1325  634033286   1/15/2014        3394       81.73      56.67      277391.62
# 1326  559183347   5/21/2014        3633      205.70     117.11      747308.10
# 1327  781416594  12/23/2015        7390      421.89     364.69     3117767.10
# 1328  713357150    6/3/2012        7088      109.28      35.84      774576.64
# 1329  906794202   5/11/2014        9410      109.28      35.84     1028324.80
#
#       Total Cost  Total Profit
# ...

# %%
# Showing data types
EuropeSales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1330 non-null   object
#  1   Country         1330 non-null   object
#  2   Item Type       1330 non-null   object
#  3   Sales Channel   1330 non-null   object
#  4   Order Priority  1330 non-null   object
#  5   Order Date      1330 non-null   object
#  6   Order ID        1330 non-null   int64
#  7   Ship Date       1330 non-null   object
#  8   Units Sold      1330 non-null   int64
#  9   Unit Price      1330 non-null   float64
#  10  Unit Cost       1330 non-null   float64
#  11  Total Revenue   1330 non-null   float64
#  12  Total Cost      1330 non-null   float64
#  13  Total Profit    1330 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 145.6+ KB

# %%
# Showing total rows and columns
EuropeSales.shape
# Out:
# (1330, 14)

# %%
# Looking at unique values
EuropeSales.nunique()
# Out:
# Region               1
# Country             48
# Item Type           12
# Sales Channel        2
# Order Priority       4
# Order Date        1049
# Order ID          1330
# Ship Date         1070
# Units Sold        1240
# Unit Price          12
# Unit Cost           12
# Total Revenue     1323
# Total Cost        1323
# Total Profit      1323
# dtype: int64

# %%
# Pulling one column 
EuropeSales["Country"]
# Out:
# 0               Czech Republic
# 1       Bosnia and Herzegovina
# 2                      Austria
# 3                     Bulgaria
# 4                      Estonia
#                  ...
# 1325                    Norway
# 1326                   Ukraine
# 1327                   Armenia
# 1328                   Denmark
# 1329                   Finland
# Name: Country, Length: 1330, dtype: object

# %%
# Correcting some data types
EuropeSales["Unit Price"] = EuropeSales["Unit Price"].astype("int")
EuropeSales["Unit Cost"] = EuropeSales["Unit Cost"].astype("int")
EuropeSales["Total Revenue"] = EuropeSales["Total Revenue"].astype("int")
EuropeSales["Total Cost"] = EuropeSales["Total Cost"].astype("int")
EuropeSales["Total Profit"] = EuropeSales["Total Profit"].astype("int")
EuropeSales["Order Date"] = EuropeSales["Order Date"].astype("datetime64[ns]")
EuropeSales["Ship Date"] = EuropeSales["Ship Date"].astype("datetime64[ns]")

# %%
# dropping duplicates
EuropeSales.drop_duplicates()
# Out:
#       Region                 Country        Item Type Sales Channel  \
# 0     Europe          Czech Republic        Beverages       Offline
# 1     Europe  Bosnia and Herzegovina          Clothes        Online
# 2     Europe                 Austria           Cereal       Offline
# 3     Europe                Bulgaria  Office Supplies        Online
# 4     Europe                 Estonia           Fruits        Online
# ...      ...                     ...              ...           ...
# 1325  Europe                  Norway    Personal Care       Offline
# 1326  Europe                 Ukraine           Cereal       Offline
# 1327  Europe                 Armenia             Meat       Offline
# 1328  Europe                 Denmark          Clothes       Offline
# 1329  Europe                 Finland          Clothes        Online
#
#      Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# ...

# %%
# Pulling spesific rows by isin function
Two_Item_Type = ["Cereal" ,"Meal"]
EuropeSales["Item Type"].isin(Two_Item_Type)
EuropeSales[EuropeSales["Item Type"].isin(Two_Item_Type)].sort_index(ascending=True)
# Out:
#       Region         Country Item Type Sales Channel Order Priority  \
# 2     Europe         Austria    Cereal       Offline              C
# 6     Europe  Czech Republic    Cereal        Online              M
# 30    Europe          Norway    Cereal        Online              M
# 58    Europe        Portugal    Cereal        Online              C
# 78    Europe         Andorra    Cereal        Online              H
# ...      ...             ...       ...           ...            ...
# 1276  Europe          Latvia    Cereal       Offline              M
# 1286  Europe          Sweden    Cereal        Online              L
# 1299  Europe          Poland    Cereal        Online              C
# 1301  Europe         Romania    Cereal        Online              L
# 1326  Europe         Ukraine    Cereal       Offline              L
#
#      Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 2    2014-08-13  987410676 2014-09-06        5616         205        117
# ...

# %%
# Pulling speesific row by str.contains 
EuropeSales[EuropeSales["Sales Channel"].str.contains("Online")]
# Out:
#       Region                 Country        Item Type Sales Channel  \
# 1     Europe  Bosnia and Herzegovina          Clothes        Online
# 3     Europe                Bulgaria  Office Supplies        Online
# 4     Europe                 Estonia           Fruits        Online
# 6     Europe          Czech Republic           Cereal        Online
# 8     Europe             Switzerland             Meat        Online
# ...      ...                     ...              ...           ...
# 1316  Europe          Czech Republic       Vegetables        Online
# 1317  Europe                 Denmark          Clothes        Online
# 1321  Europe             Switzerland        Beverages        Online
# 1324  Europe                 Belarus       Vegetables        Online
# 1329  Europe                 Finland          Clothes        Online
#
#      Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# ...

# %%
# Setting index
EuropeSales2 = EuropeSales.set_index("Country")
EuropeSales2
# Out:
#                         Region        Item Type Sales Channel Order Priority  \
# Country
# Czech Republic          Europe        Beverages       Offline              C
# Bosnia and Herzegovina  Europe          Clothes        Online              M
# Austria                 Europe           Cereal       Offline              C
# Bulgaria                Europe  Office Supplies        Online              L
# Estonia                 Europe           Fruits        Online              L
# ...                        ...              ...           ...            ...
# Norway                  Europe    Personal Care       Offline              M
# Ukraine                 Europe           Cereal       Offline              L
# Armenia                 Europe             Meat       Offline              M
# Denmark                 Europe          Clothes       Offline              H
# Finland                 Europe          Clothes        Online              L
#
# ...

# %%
# Countries that made more than 1000000 money 
EuropeSales[EuropeSales["Total Revenue"] > 1000000].sort_values(by=["Item Type"])
# Out:
#      Region                 Country   Item Type Sales Channel Order Priority  \
# 650  Europe             Netherlands   Baby Food       Offline              H
# 217  Europe                 Andorra   Baby Food       Offline              M
# 629  Europe                   Italy   Baby Food       Offline              L
# 631  Europe                 Iceland   Baby Food        Online              H
# 634  Europe          United Kingdom   Baby Food        Online              H
# ..      ...                     ...         ...           ...            ...
# 931  Europe  Bosnia and Herzegovina  Vegetables        Online              H
# 498  Europe                  Serbia  Vegetables       Offline              M
# 934  Europe                 Andorra  Vegetables        Online              C
# 946  Europe                  Serbia  Vegetables        Online              C
# 308  Europe                  Sweden  Vegetables        Online              C
#
# ...

# %%
# Beverages sales more than 6000 and as of 01/01/2013
is_beverages = EuropeSales["Item Type"] == "Beverages"
is_sales_over_6000 = EuropeSales["Units Sold"] > 6000
is_ship_date_as_of_2012 = EuropeSales["Ship Date"] > "12/31/2012"

# %%
EuropeSales[is_beverages & is_sales_over_6000 & is_ship_date_as_of_2012]
# Out:
#       Region                 Country  Item Type Sales Channel Order Priority  \
# 67    Europe                 Hungary  Beverages        Online              L
# 82    Europe                  Poland  Beverages       Offline              C
# 98    Europe                 Estonia  Beverages       Offline              C
# 261   Europe              San Marino  Beverages       Offline              M
# 285   Europe                  Cyprus  Beverages        Online              M
# 330   Europe                Slovakia  Beverages        Online              M
# 351   Europe                 Belarus  Beverages        Online              H
# 423   Europe                  Latvia  Beverages       Offline              L
# 435   Europe                 Iceland  Beverages        Online              L
# 437   Europe                  Norway  Beverages       Offline              L
# 535   Europe                  Greece  Beverages       Offline              H
# ...

# %%
# Sales between 2015 and 2017
EuropeSales[EuropeSales["Ship Date"].between("01/01/2015" ,"12/31/2017")]
# Out:
#       Region                 Country        Item Type Sales Channel  \
# 4     Europe                 Estonia           Fruits        Online
# 5     Europe              Montenegro           Fruits       Offline
# 10    Europe                 Belgium           Snacks        Online
# 12    Europe  Bosnia and Herzegovina        Baby Food        Online
# 13    Europe             Netherlands             Meat       Offline
# ...      ...                     ...              ...           ...
# 1304  Europe                   Malta             Meat        Online
# 1310  Europe                 Austria  Office Supplies       Offline
# 1312  Europe                   Italy       Vegetables       Offline
# 1320  Europe                 Hungary          Clothes       Offline
# 1327  Europe                 Armenia             Meat       Offline
#
#      Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# ...

# %%
# Shipping time
EuropeSales["Shipping Time"] = EuropeSales["Ship Date"] - EuropeSales["Order Date"]

# %%
# Grouping by categories
categories = EuropeSales.groupby("Item Type")

# %%
# Looking at total values by categories
categories.sum()
# Out:
# C:\Users\Oğuzhan\AppData\Local\Temp\ipykernel_12776\2113278352.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   categories.sum()
#                     Order ID  Units Sold  Unit Price  Unit Cost  \
# Item Type
# Baby Food        55860289378      562706       28560      17808
# Beverages        68325459118      613133        5687       3751
# Cereal           56569505029      465685       21115      12051
# Clothes          54226855641      591385       11445       3675
# Cosmetics        58643057311      533291       49818      29982
# Fruits           58467051926      591672        1008        672
# Household        56177671279      440249       64796      48694
# Meat             66277822401      533376       46731      40404
# ...

# %%
# Looking at average values by categories
categories.mean()
# Out:
# C:\Users\Oğuzhan\AppData\Local\Temp\ipykernel_12776\935082138.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   categories.mean()
#                      Order ID   Units Sold  Unit Price  Unit Cost  \
# Item Type
# Baby Food        4.987526e+08  5024.160714       255.0      159.0
# Beverages        5.646732e+08  5067.214876        47.0       31.0
# Cereal           5.492185e+08  4521.213592       205.0      117.0
# Clothes          5.164462e+08  5632.238095       109.0       35.0
# Cosmetics        5.144128e+08  4677.991228       437.0      263.0
# Fruits           5.220272e+08  5282.785714         9.0        6.0
# Household        5.791513e+08  4538.649485       668.0      502.0
# Meat             5.970975e+08  4805.189189       421.0      364.0
# ...

# %%
# Looking at sales values by aggregation  
EuropeSales.groupby("Item Type").agg({"Total Profit":["sum","mean","min","max","std"]})
# Out:
#                 Total Profit
#                          sum           mean   min      max            std
# Item Type
# Baby Food           53940943  481615.562500  4409   955532  277193.171615
# Beverages            9601601   79352.074380  1785   155394   45366.357844
# Cereal              41254980  400533.786408  4429   881470  250370.555628
# Clothes             43431264  413631.085714  9033   734106  213404.652252
# Cosmetics           92723254  813361.877193  2955  1700448  530891.321950
# Fruits               1425877   12731.044643   130    23998    6972.966563
# Household           72962417  752189.865979   331  1654814  473089.668898
# Meat                30509065  274856.441441   972   568911  177110.710432
# Office Supplies     77977131  633960.414634   252  1262121  374300.452751
# Personal Care       14045573  122135.417391  1779   250574   72097.098435
# Snacks              27027373  262401.679612  9428   547485  151878.278241
# ...

# %%
# Importing matplotlib to visualize dataset
import matplotlib.pyplot as plt

# %%
# Preparing data to visualization
Categories = EuropeSales.groupby("Item Type").sum()
Items = EuropeSales["Item Type"].unique()
Categories_Average = EuropeSales.groupby("Item Type").mean()
# Out:
# C:\Users\Oğuzhan\AppData\Local\Temp\ipykernel_12776\1732815754.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Categories = EuropeSales.groupby("Item Type").sum()
# C:\Users\Oğuzhan\AppData\Local\Temp\ipykernel_12776\1732815754.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Categories_Average = EuropeSales.groupby("Item Type").mean()

# %%
# Total profits of every categories
plt.bar(Items , Categories["Total Profit"] , color= "#1dc6f0")

plt.xticks(rotation = "vertical" , size = 10)

plt.xlabel("Categories")

plt.ylabel("Profits")

plt.title("Total Profits By Categories")

plt.show()

# %%
# Top 5 countries by revenue
Top_Five_Countries = (EuropeSales.groupby("Country").agg({"Total Revenue":"sum"})
.sort_values("Total Revenue" ,ascending=False).iloc[:5])

# %%
# Bar graph of top 5 countries
colors = ["#db1414" ,"#200e6e", "#21ed21" ,"#2394eb" ,"#c910a7"]
labels = ["Kosova","Czech Republic","Ukraine","Bosnia and Herzegovina","Macedonia"]

plt.pie(Top_Five_Countries['Total Revenue'] ,colors = colors ,labels=labels ,autopct = "%.0f%%")

plt.title("Top 5 Countries By Total Revenue")

plt.show()

# %%
bins = [20000,40000,60000,80000,100000,120000,140000,160000,180000,200000]

plt.hist(countries["Units Sold"] ,bins=bins ,color="#53db18")

plt.title("Total Sales By Countries")

plt.xlabel("Number Of Sales")

plt.ylabel("Number Of Country")

plt.show()

# %%
# Distribution of average profit and sales of categories
plt.scatter(Categories_Average["Total Profit"] ,Categories_Average["Units Sold"] ,alpha = 0.5 ,color ="#2394eb",s=100)

plt.ylabel("Average Sales By Categories")

plt.xlabel("Average Profits By Categories")

plt.title("Average Sales And Average Profits Comparison")

plt.show()
